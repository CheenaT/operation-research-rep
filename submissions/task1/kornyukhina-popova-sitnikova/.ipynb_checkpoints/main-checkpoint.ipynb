# %%
import numpy as np
from scipy.optimize import linprog
from fractions import Fraction
from math import fabs
import matplotlib.pyplot as plt
from mypackage import *

# %%
a = np.array(([4,0,6,2,2,1],[3,8,4,10,4,4],[1,2,6,5,0,0],[6,6,4,4,10,3],[10,4,6,4,0,9],[10,7,0,7,9,8]))
print("Матрица выигрыша:")
output_matrix(a)
# Out:
# Матрица выигрыша:
# |  4 | 0 | 6 |  2 |  2 | 1 |
# |  3 | 8 | 4 | 10 |  4 | 4 |
# |  1 | 2 | 6 |  5 |  0 | 0 |
# |  6 | 6 | 4 |  4 | 10 | 3 |
# | 10 | 4 | 6 |  4 |  0 | 9 |
# | 10 | 7 | 0 |  7 |  9 | 8 |

# %%
p,q,price_game = nash_equilibrium(a)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: 151/31
# Решения:
# 1 игрок: | 0 | 4/31 | 3/31 | 27/62 | 21/62 | 0 |
# 2 игрок: | 0 | 0 | 257/372 | 9/62 | 55/372 | 1/62 |

# %%
b = np.array(([-1,1],[1,-1]))
print("Матрица выигрыша:")
output_matrix(b)
# Out:
# Матрица выигрыша:
# | -1 |  1 |
# |  1 | -1 |

# %%
p,q,price_game = nash_equilibrium(b)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: 0
# Решения:
# 1 игрок: | 1/2 | 1/2 |
# 2 игрок: | 1/2 | 1/2 |

# %%
c = np.array(([3,1],[1,1])) #седловая точка. равновесие. игра в чистых стратегиях
print("Матрица выигрыша:")
output_matrix(c)
# Out:
# Матрица выигрыша:
# | 3 | 1 |
# | 1 | 1 |

# %%
p,q,price_game = nash_equilibrium(c)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: 1
# Решения:
# 1 игрок: | 1 | 0 |
# 2 игрок: | 0 | 1 |

# %%
d = np.array(([5,-1],[2,3]))
print("Матрица выигрыша:")
output_matrix(d)
# Out:
# Матрица выигрыша:
# | 5 | -1 |
# | 2 |  3 |

# %%
p,q,price_game = nash_equilibrium(d)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: 17/7
# Решения:
# 1 игрок: | 1/7 | 6/7 |
# 2 игрок: | 4/7 | 3/7 |

# %%
e = np.array(([5,6,7],[3,3,3],[2,1,0]))
print("Матрица выигрыша:")
output_matrix(e)
# Out:
# Матрица выигрыша:
# | 5 | 6 | 7 |
# | 3 | 3 | 3 |
# | 2 | 1 | 0 |

# %%
p,q,price_game = nash_equilibrium(e)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: 5
# Решения:
# 1 игрок: | 1 | 0 | 0 |
# 2 игрок: | 1 | 0 | 0 |

# %%
f = np.array(([51234,2134,71234],[2243,11243,1231],[32,21,1531],[432,21,124]))
print("Матрица выигрыша:")
output_matrix(f)
# Out:
# Матрица выигрыша:
# | 51234 |  2134 | 71234 |
# |  2243 | 11243 |  1231 |
# |    32 |    21 |  1531 |
# |   432 |    21 |   124 |

# %%
p,q,price_game = nash_equilibrium(f)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: 5712373/581
# Решения:
# 1 игрок: | 90/581 | 491/581 | 0 | 0 |
# 2 игрок: | 9109/58100 | 48991/58100 | 0 |

# %%
g = np.array(([0.5,0.6,0.8],[0.9,0.7,0.8],[0.7,0.6,0.6])) #седловая точка. равновесие. игра в чистых стратегиях
print("Матрица выигрыша:")
output_matrix(g)
# Out:
# Матрица выигрыша:
# | 0.5 | 0.6 | 0.8 |
# | 0.9 | 0.7 | 0.8 |
# | 0.7 | 0.6 | 0.6 |

# %%
p,q,price_game = nash_equilibrium(g)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: 7/10
# Решения:
# 1 игрок: | 0 | 1 | 0 |
# 2 игрок: | 0 | 1 | 0 |

# %%
h = np.array(([1,-1,-1],[-1,-1,-1])) #спектр неполон
print("Матрица выигрыша:")
output_matrix(h)
# Out:
# Матрица выигрыша:
# |  1 | -1 | -1 |
# | -1 | -1 | -1 |

# %%
p,q,price_game = nash_equilibrium(h)
print("Значение:", Fraction(price_game).limit_denominator())
print("Решения:")
print("1 игрок: ",end='')
output_decision(p)
print()
print("2 игрок: ",end='')
output_decision(q)
visualize(p)
visualize(q)
# Out:
# Значение: -1
# Решения:
# 1 игрок: | 1 | 0 |
# 2 игрок: | 0 | 1 | 0 |
