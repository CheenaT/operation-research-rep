# %%
import numpy as np

from nash_equilibrium.simplex_method import nash_equilibrium, print_result

# %%
tab = np.array([
    [4,0,6,2,2,1],
    [3,8,4,10,4,4],
    [1,2,6,5,0,0],
    [6,6,4,4,10,3],
    [10,4,6,4,0,9],
    [10,7,0,7,9,8]
])

# %%
p, q, price, flag = nash_equilibrium(tab)

# %%
print_result(p, q, price, flag)
# Out:
# Цена игры  151/31
# Оптимальная смешанная стратегия 1 игрока | p | |   0   |  4/31 |  3/31 | 27/62 | 21/62 |   0   |
#
# Оптимальная смешанная стратегия 2 игрока | q | |   0   |   0   |257/372|  9/62 | 55/372|  1/62 |
